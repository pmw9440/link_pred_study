# %%
from ogb.linkproppred import PygLinkPropPredDataset

# %%
#collab
dataset = PygLinkPropPredDataset(name="ogbl-collab")
data = dataset[0]
print('dataset meta info', dataset.meta_info)
print("collab: ", data, type(data))
# Out:
# dataset meta info eval metric                                                        hits@50
# task type                                                  link prediction
# download_name                                                       collab
# version                                                                  1
# url                      http://snap.stanford.edu/ogb/data/linkproppred...
# add_inverse_edge                                                      True
# has_node_attr                                                         True
# has_edge_attr                                                        False
# split                                                                 time
# additional node files                                                 None
# additional edge files                                edge_weight,edge_year
# is hetero                                                            False
# ...

# %%
# ppa
dataset = PygLinkPropPredDataset(name="ogbl-ppa")
data = dataset[0]
print('dataset meta info', dataset.meta_info)
print("ppa: ", data, type(data))
# Out:
# ...
# Downloaded 0.38 GB: 100%|██████████| 388/388 [00:30<00:00, 12.68it/s]
# Extracting dataset\ppassoc.zip
# Processing...
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████| 1/1 [00:00<00:00,  4.28it/s]
# Converting graphs into PyG objects...
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Saving...
# Done!
# ...

# %%
# ddi
dataset = PygLinkPropPredDataset(name="ogbl-ddi")
data = dataset[0]
print('dataset meta info', dataset.meta_info)
print("ddi: ", data, type(data))
# Out:
# ...
# Downloaded 0.04 GB: 100%|██████████| 46/46 [00:04<00:00,  9.47it/s]
# Extracting dataset\ddi.zip
# Processing...
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Converting graphs into PyG objects...
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Saving...
# dataset meta info eval metric                                                        hits@20
# task type                                                  link prediction
# download_name                                                          ddi
# version                                                                  1
# url                      http://snap.stanford.edu/ogb/data/linkproppred...
# add_inverse_edge                                                      True
# has_node_attr                                                        False
# has_edge_attr                                                        False
# ...
