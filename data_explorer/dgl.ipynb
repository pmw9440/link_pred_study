# %%
from datasets import load_dataset

# 전체를 다운로드하지 않고 즉시 가져오기
dataset = load_dataset("Yelp/yelp_review_full", streaming=True)

# 첫 번째 아이템 확인
print(next(iter(dataset['train'])))
# Out:
# ...
# {'label': 4, 'text': "dr. goldberg offers everything i look for in a general practitioner.  he's nice and easy to talk to without being patronizing; he's always on time in seeing his patients; he's affiliated with a top-notch hospital (nyu) which my parents have explained to me is very important in case something happens and you need surgery; and you can get referrals to see specialists without having to see him first.  really, what more do you need?  i'm sitting here trying to think of any complaints i have about him, but i'm really drawing a blank."}

# %%
from recbole.quick_start import run_recbole

# 샘플 데이터셋(ml-100k)과 BPR 모델로 정상 동작 테스트
run_recbole(model='BPR', dataset='ml-100k')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from recbole.quick_start import run_recbole
#       2
#       3 # 샘플 데이터셋(ml-100k)과 BPR 모델로 정상 동작 테스트
#       4 run_recbole(model='BPR', dataset='ml-100k')
#
# File c:\Users\pmw\AppData\Local\pypoetry\Cache\virtualenvs\data-explorer-l-INJnYo-py3.11\Lib\site-packages\recbole\quick_start\__init__.py:1
# ----> 1 from recbole.quick_start.quick_start import (
#       2     run,
#       3     run_recbole,
#       4     objective_function,
#       5     load_data_and_model,
#       6     run_recboles,
#       7 )
#
# File c:\Users\pmw\AppData\Local\pypoetry\Cache\virtualenvs\data-explorer-l-INJnYo-py3.11\Lib\site-packages\recbole\quick_start\quick_start.py:20
#      17 from collections.abc import MutableMapping
#      18 from logging import getLogger
# ---> 20 from ray import tune
# ...
