# %%
from torch_geometric.datasets import Planetoid

# %%
# Cora
dataset = Planetoid(root="dataset", name="Cora")
data = dataset[0]
print("Cora data: ", data)
# Out:
# Cora data: Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])

# %%
# Citeseer
dataset = Planetoid(root='dataset', name="Citeseer")
data = dataset[0]
print("Citeseer: ", data)
# Out:
# Citeseer:  Data(x=[3327, 3703], edge_index=[2, 9104], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])

# %%
#Pubmed
dataset = Planetoid(root="dataset", name="Pubmed")
data = dataset[0]
print("Pubmed: ", data)
# Out:
# ...
# Processing...
# Pubmed:  Data(x=[19717, 500], edge_index=[2, 88648], y=[19717], train_mask=[19717], val_mask=[19717], test_mask=[19717])
# Done!

# %%
# Movie Lens
from torch_geometric.datasets import MovieLens
dataset = MovieLens(root="dataset/MovieLens")
data = dataset[0]

print("MovieLens: ", data)
# Out:
# Processing...
# c:\Users\pmw\AppData\Local\pypoetry\Cache\virtualenvs\data-explorer-l-INJnYo-py3.11\Lib\site-packages\torch_geometric\datasets\movie_lens.py:79: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_numpy.cpp:212.)
#   genres = torch.from_numpy(genres).to(torch.float)
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# ...
